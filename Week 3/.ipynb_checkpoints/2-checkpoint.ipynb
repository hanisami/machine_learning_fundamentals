# %%
import numpy as np
x = np.arange(0,100).reshape(100,1)
y = (3 + (4 * x)) + np.random.randint(-50, 100, (100, 1))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.scatterplot(x.flatten(),y.flatten())
ax.set(xlabel='X', ylabel='Y')
plt.show()
# Out:
# /Users/hanisami/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# y = 3 * x + 4

# %%
# lr = [3*x_i + 3 for x_i in x]
lr1 = [4*x_i + 40 for x_i in x]
lr2 = [5*x_i + 80 for x_i in x]
lr3 = [6*x_i + 120 for x_i in x]
lr4 = [7*x_i + 160 for x_i in x]
lr5 = [2*x_i + 10 for x_i in x]

# %%
# Plot scatter plot of x and y
sns.scatterplot(x=x.flatten(), y=y.flatten())

# Plot linear regression line
sns.lineplot(x=x.flatten(), y=np.array(lr).flatten(), color='red', label='y = 4x + 40')
sns.lineplot(x=x.flatten(), y=np.array(lr1).flatten(), color='green')
sns.lineplot(x=x.flatten(), y=np.array(lr2).flatten(), color='black')
sns.lineplot(x=x.flatten(), y=np.array(lr3).flatten(), color='orange')
sns.lineplot(x=x.flatten(), y=np.array(lr4).flatten(), color='purple')

# Set plot labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression')

# Show the plot
plt.show()
